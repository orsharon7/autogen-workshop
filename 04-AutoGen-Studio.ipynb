# %% [markdown]
# # AutoGen Studio
#
# https://microsoft.github.io/autogen/docs/autogen-studio/getting-started

# %%
# %pip install autogenstudio
# Out:
# Requirement already satisfied: autogenstudio in /opt/anaconda3/lib/python3.11/site-packages (0.1.2)
# Requirement already satisfied: pydantic in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (2.7.4)
# Requirement already satisfied: fastapi in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (0.110.3)
# Requirement already satisfied: typer in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (0.9.4)
# Requirement already satisfied: uvicorn in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (0.23.2)
# Requirement already satisfied: arxiv in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (2.1.2)
# Requirement already satisfied: pyautogen>=0.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen[gemini]>=0.2.0->autogenstudio) (0.2.31)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (0.21.0)
# Requirement already satisfied: websockets in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (12.0)
# Requirement already satisfied: numpy<2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (1.26.4)
# Requirement already satisfied: sqlmodel in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (0.0.19)
# Requirement already satisfied: psycopg in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (3.1.19)
# Requirement already satisfied: alembic in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (1.13.1)
# Requirement already satisfied: loguru in /opt/anaconda3/lib/python3.11/site-packages (from autogenstudio) (0.7.2)
# Requirement already satisfied: diskcache in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (5.6.3)
# Requirement already satisfied: docker in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (7.1.0)
# Requirement already satisfied: flaml in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (2.1.2)
# Requirement already satisfied: openai>=1.3 in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (1.26.0)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (23.2)
# Requirement already satisfied: termcolor in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (2.4.0)
# Requirement already satisfied: tiktoken in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (0.6.0)
# Requirement already satisfied: google-auth in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen[gemini]>=0.2.0->autogenstudio) (2.30.0)
# Requirement already satisfied: google-cloud-aiplatform in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen[gemini]>=0.2.0->autogenstudio) (1.56.0)
# Requirement already satisfied: google-generativeai<1,>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen[gemini]>=0.2.0->autogenstudio) (0.7.0)
# Requirement already satisfied: pillow in /opt/anaconda3/lib/python3.11/site-packages (from pyautogen[gemini]>=0.2.0->autogenstudio) (10.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic->autogenstudio) (0.6.0)
# Requirement already satisfied: pydantic-core==2.18.4 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic->autogenstudio) (2.18.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic->autogenstudio) (4.9.0)
# Requirement already satisfied: SQLAlchemy>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from alembic->autogenstudio) (2.0.25)
# Requirement already satisfied: Mako in /opt/anaconda3/lib/python3.11/site-packages (from alembic->autogenstudio) (1.3.5)
# Requirement already satisfied: feedparser~=6.0.10 in /opt/anaconda3/lib/python3.11/site-packages (from arxiv->autogenstudio) (6.0.11)
# Requirement already satisfied: requests~=2.32.0 in /opt/anaconda3/lib/python3.11/site-packages (from arxiv->autogenstudio) (2.32.3)
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /opt/anaconda3/lib/python3.11/site-packages (from fastapi->autogenstudio) (0.37.2)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from typer->autogenstudio) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /opt/anaconda3/lib/python3.11/site-packages (from uvicorn->autogenstudio) (0.14.0)
# Requirement already satisfied: sgmllib3k in /opt/anaconda3/lib/python3.11/site-packages (from feedparser~=6.0.10->arxiv->autogenstudio) (1.0.0)
# Requirement already satisfied: google-ai-generativelanguage==0.6.5 in /opt/anaconda3/lib/python3.11/site-packages (from google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (0.6.5)
# Requirement already satisfied: google-api-core in /opt/anaconda3/lib/python3.11/site-packages (from google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (2.19.0)
# Requirement already satisfied: google-api-python-client in /opt/anaconda3/lib/python3.11/site-packages (from google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (2.134.0)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.11/site-packages (from google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (4.25.3)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.11/site-packages (from google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (4.65.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /opt/anaconda3/lib/python3.11/site-packages (from google-ai-generativelanguage==0.6.5->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (1.24.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth->pyautogen[gemini]>=0.2.0->autogenstudio) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth->pyautogen[gemini]>=0.2.0->autogenstudio) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth->pyautogen[gemini]>=0.2.0->autogenstudio) (4.9)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai>=1.3->pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai>=1.3->pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/lib/python3.11/site-packages (from openai>=1.3->pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (0.27.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from openai>=1.3->pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests~=2.32.0->arxiv->autogenstudio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests~=2.32.0->arxiv->autogenstudio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests~=2.32.0->arxiv->autogenstudio) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests~=2.32.0->arxiv->autogenstudio) (2024.6.2)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (2.17.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (3.25.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (1.12.3)
# Requirement already satisfied: shapely<3.0.0dev in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (2.0.4)
# Requirement already satisfied: docstring-parser<1 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (0.16)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /opt/anaconda3/lib/python3.11/site-packages (from Mako->alembic->autogenstudio) (2.1.3)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/lib/python3.11/site-packages (from tiktoken->pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (2023.10.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (1.63.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.5->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (1.64.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.5->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (1.62.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (2.7.1)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (0.13.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (1.5.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai>=1.3->pyautogen>=0.2.0->pyautogen[gemini]>=0.2.0->autogenstudio) (1.0.5)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth->pyautogen[gemini]>=0.2.0->autogenstudio) (0.4.8)
# Requirement already satisfied: httplib2<1.dev0,>=0.19.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-python-client->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-python-client->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-api-python-client->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /opt/anaconda3/lib/python3.11/site-packages (from httplib2<1.dev0,>=0.19.0->google-api-python-client->google-generativeai<1,>=0.5->pyautogen[gemini]>=0.2.0->autogenstudio) (3.0.9)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform->pyautogen[gemini]>=0.2.0->autogenstudio) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
! autogenstudio ui --port 8081 --appdir ./autogenstudio/
# Out:
# 2024-07-13 15:57:29.513 | INFO     | autogenstudio.utils.utils:get_db_uri:253 - Using database URI: sqlite:///./autogenstudio/database.sqlite
# 2024-07-13 15:57:29.513 | INFO     | autogenstudio.utils.utils:init_app_folders:288 - Initialized application data folder: ./autogenstudio/
# INFO:     Started server process [80409]
# INFO:     Waiting for application startup.
# ***** App started *****
# 2024-07-13 15:57:29.537 | INFO     | autogenstudio.database.utils:init_db_samples:148 - Database already initialized with Default and Travel Planning Workflows
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8081 (Press CTRL+C to quit)
# INFO:     127.0.0.1:64327 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64328 - "GET /app-528798f9e5263504af31.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64327 - "GET /images/svgs/welcome.svg HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64329 - "GET /framework-cac843a6fec86b8bc39a.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /webpack-runtime-8a9cec42747aac4b7ac0.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64329 - "GET /page-data/app-data.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64328 - "GET /page-data/index/page-data.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64332 - "GET /manifest.webmanifest HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64328 - "GET /component---src-pages-index-tsx-63b85e072a7479d6d32f.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64329 - "GET /318ce576f236b79fd96f75904c13f6e55c3eee57-40536b969c9ad93bcc1c.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64329 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64328 - "GET /api/version HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 64333) - "WebSocket /api/ws/6b4b331d-8267-450a-a92e-ce03cec7cc36" [accepted]
# New Connection: 6b4b331d-8267-450a-a92e-ce03cec7cc36, Total: 1
# INFO:     connection open
# INFO:     127.0.0.1:64330 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64329 - "GET /api/sessions/5/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64329 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /api/sessions/5/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /api/workflows?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /page-data/build/page-data.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /component---src-pages-build-tsx-bf9ad8b79ecb0e409aa9.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "POST /api/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64330 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64329 - "GET /api/sessions/6/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# Client says: user_message
# 2024-07-13 15:57:51.784 | ERROR    | autogenstudio.utils.utils:load_code_execution_config:435 - Error initializing Docker executor: Error while fetching server API version: ('Connection aborted.', FileNotFoundError(2, 'No such file or directory'))
# **** pool **** {<CodeExecutionConfigTypes.local: 'local'>: {'executor': <autogen.coding.local_commandline_code_executor.LocalCommandLineCodeExecutor object at 0x309932090>}, <CodeExecutionConfigTypes.docker: 'docker'>: False} **** False
# **** pool **** {<CodeExecutionConfigTypes.local: 'local'>: {'executor': <autogen.coding.local_commandline_code_executor.LocalCommandLineCodeExecutor object at 0x309932090>}, <CodeExecutionConfigTypes.docker: 'docker'>: False} **** {'executor': <autogen.coding.local_commandline_code_executor.LocalCommandLineCodeExecutor object at 0x309932090>}
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogenstudio/web/app.py", line 453, in run_session_workflow
#     agent_response: Message = managers["chat"].chat(
#                               ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogenstudio/chatmanager.py", line 79, in chat
#     result_message: Message = workflow_manager.run(message=f"{message_text}", clear_history=False, history=history)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogenstudio/workflowmanager.py", line 400, in run
#     self._run_workflow(message=message, history=history,
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogenstudio/workflowmanager.py", line 98, in _run_workflow
#     self.sender = self.load(agent.get("agent"))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogenstudio/workflowmanager.py", line 300, in load
#     agent = ExtendedConversableAgent(
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogenstudio/workflowmanager.py", line 666, in __init__
#     super().__init__(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py", line 159, in __init__
#     self._validate_llm_config(llm_config)
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogen/agentchat/conversable_agent.py", line 263, in _validate_llm_config
#     self.client = None if self.llm_config is False else OpenAIWrapper(**self.llm_config)
#                                                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogen/oai/client.py", line 413, in __init__
#     self._register_default_client(extra_kwargs, openai_config)
#   File "/opt/anaconda3/lib/python3.11/site-packages/autogen/oai/client.py", line 488, in _register_default_client
#     client = OpenAI(**openai_config)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/openai/_client.py", line 104, in __init__
#     raise OpenAIError(
# openai.OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable
#
# INFO:     127.0.0.1:64355 - "GET /api/workflows/1?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64356 - "GET /api/sessions/4/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# None
# INFO:     127.0.0.1:64356 - "GET /api/profiler/12?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64356 - "GET /355a6ca7-7d3ff1df35f7958f1b25.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64355 - "GET /614-45ec4d8cce7508cad991.js HTTP/1.1" 200 OK
# None
# INFO:     127.0.0.1:64358 - "GET /api/profiler/14?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64498 - "GET /api/version HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64498 - "GET /api/sessions/6/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 64500) - "WebSocket /api/ws/4c6b37d0-1196-4540-b6a5-01e29ba2f97d" [accepted]
# New Connection: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d, Total: 2
# INFO:     connection open
# INFO:     127.0.0.1:64498 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/sessions/6/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/workflows?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/workflows?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# Client #4c6b37d0-1196-4540-b6a5-01e29ba2f97d is disconnected
# Connection Closed. Total: 1
# INFO:     connection closed
# INFO:     127.0.0.1:64497 - "GET /api/agents?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64499 - "GET /api/workflows/link/agent/2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/workflows?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/agents?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/models?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64501 - "GET /api/agents/link/model/2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64501 - "GET /api/skills?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/agents/link/skill/2 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64501 - "GET /api/agents?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64501 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 64504) - "WebSocket /api/ws/4c6b37d0-1196-4540-b6a5-01e29ba2f97d" [accepted]
# New Connection: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d, Total: 2
# INFO:     127.0.0.1:64505 - "GET /api/sessions/6/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     connection open
# INFO:     127.0.0.1:64505 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64497 - "GET /api/sessions/6/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64505 - "GET /api/workflows?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64505 - "POST /api/sessions HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64505 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64505 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64508 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# Client says: user_message
# 2024-07-13 16:04:36.761 | ERROR    | autogenstudio.utils.utils:load_code_execution_config:435 - Error initializing Docker executor: Error while fetching server API version: ('Connection aborted.', FileNotFoundError(2, 'No such file or directory'))
# **** pool **** {<CodeExecutionConfigTypes.local: 'local'>: {'executor': <autogen.coding.local_commandline_code_executor.LocalCommandLineCodeExecutor object at 0x30587fa10>}, <CodeExecutionConfigTypes.docker: 'docker'>: False} **** {'executor': <autogen.coding.local_commandline_code_executor.LocalCommandLineCodeExecutor object at 0x30587fa10>}
# **** pool **** {<CodeExecutionConfigTypes.local: 'local'>: {'executor': <autogen.coding.local_commandline_code_executor.LocalCommandLineCodeExecutor object at 0x30587fa10>}, <CodeExecutionConfigTypes.docker: 'docker'>: False} **** False
# user_proxy2024-07-13 16:04:36.785 | INFO     | autogenstudio.web.app:message_handler:38 - ** Processing Agent Message on Queue: Active Connections: ['6b4b331d-8267-450a-a92e-ce03cec7cc36', '4c6b37d0-1196-4540-b6a5-01e29ba2f97d'] **
#  2024-07-13 16:04:36.785 | INFO     | autogenstudio.web.app:message_handler:50 - Skipping message for connection_id: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d. Connection ID: 6b4b331d-8267-450a-a92e-ce03cec7cc36
# 2024-07-13 16:04:36.785 | INFO     | autogenstudio.web.app:message_handler:45 - Sending message to connection_id: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d. Connection ID: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d
# (to default_assistant):
#
# I want you to take the following text and generate a system prompt for my AI assistant for dog owners, called Freddie: " Pet food labels » How to read them in 60 SECONDS (youtube.com)
#
# 0 - 11.44
# So the thing about having pets is because we've taken them into our lives, our houses, and our worlds, they don't really get the option to go hunt for their own dinners. And that's where we come in. So we go out and head to the pet store and try to
# 11.44 - 29.5
# choose food for our animals. And we are presented with aisles and aisles of beautiful looking foods that have pictures of happy dogs and idyllic farm scenes, beautiful juicy cuts of meat, wild cats hunting, and we think hey this food is definitely going to match what my animals need. But
# 29.5 - 41.2
# do they really? No they don't. So here's everything that you need to know to be actually sure of what you're feeding your animals. Turn that back around and look at the ingredients. The first thing that we're going to look at is in what order they're listed because obviously the
# 41.2 - 55.8
# first one listed are going to be present in higher amounts. And while that's true, yes they're listed in order of amounts but this is before they're cooked. So guess what happens when you cook it and dehydrate it to make the kibble? The amount of meat now is a majority
# 55.8 - 68.8
# of its weight which was water, while the cereals and grains and other powders that are added have maintained their weight. So there is actually in proportions a lot less meat and a lot less of the fresh ingredients than we originally thought. So we need to keep this in mind
# 68.8 - 78.42
# when we're looking at the label. And of course I have a trick for you that you can use when you are at the store and you kind of want to read a label on the fly. But before we go through that we really need to understand what we are
# 78.42 - 91.9
# reading. So what some of those words means that are written on the label. They're a lot simpler than you think and they can be really easily decoded. The name of ingredients on the label and what they have to mean is actually controlled by the AFFCO and they have very
# 91.9 - 109.46
# strict rules. So meat is just what it says. It will contain muscle and muscle can be the general skeletal muscles or it can also be the heart, the esophagus, the tongue and the diaphragm. Generally speaking it can be called meat and that means that it's farm animals or it
# 109.46 - 125.2
# can specify which animal it is. Oh and keep in mind that according to the AFFCO fish and chicken are not considered meat. Chicken is considered poultry. Fish is considered fish. But if you're a raw feeder you know that we can count chicken and fish as muscle meat and we
# 125.2 - 141.72
# can feed it kind of as meat. The next step is meat byproducts. Now that doesn't sound very good but it's actually not so bad. Byproducts are all of the clean internal organs. So if you're a raw feeder you're basically feeding this already in smallish amounts, so around 10%, sometimes
# 141.72 - 158.18
# 15 % of the diet of your animal and these can be in commercial foods as well. So as with meat, meat byproducts need to have the species specified unless it's a farm animal meat. Of course we also have poultry byproducts which unlike meat byproducts actually can contain bones, feet
# 158.18 - 176
# and heads. Again if you're a raw feeder you know that this is normal and that we always add this to our animal's diet in smaller amounts. So so far so good. And then we have the word meals. The AFFCO states that meals can contain blood, hair, hoof, horn, high
# 176 - 195.74
# trimmings, manure, stomach and rumen contents in such amounts as may occur unavoidably in good processing practices. What are good processing practices? I'm sure that we've all seen pictures or videos in some documentary of what happens in a cleanest place and it's not exactly the kind of place where it's
# 195.74 - 213.32
# easy to keep things separate. So I don't like the idea of feeding my dog and my cats meals because they may contain all of these things in small amount. And how small is the amount? So now that we've seen what the ingredients meal, let me go through a really
# 213.32 - 225.38
# easy trick on how to read these labels very quickly on the fly when you are in the grocery store or in a pet food store. The first thing that we're going to look at is in what order they're listed because obviously the first one listed are going to be
# 225.38 - 239.28
# present in higher amounts. And while that's true, I told you there's also a sneaky thing about this. So yes, they're listed in order of amounts but this is before they're cooked. So guess what happens when you cook it and dehydrate it to make the kibble. The amount of meat
# 239.28 - 252.12
# now is a lot smaller because the meat has lost the majority of its weight which was water, while the cereals and grains and other powders that are added have maintained their weight. So there is actually in proportions a lot less meat and a lot less of the fresh ingredients
# 252.12 - 264.98
# than we originally thought. So we need to keep this in mind when we're looking at the label. Now here's my thought process. The first thing that I do is check if the words meal, powder and flour are present. Now meal, I already said, I don't like it. There can
# 264.98 - 279.7
# be protein powders or meat powders or meat flowers used. They are not high quality and I would prefer not to feed my animals that. The next thing I look at is oils. Now animals need good quality fat in their diets and good quality animal fat should be called that.
# 280.26 - 295.78
# Fat. Animal oil is rendered fat and we know that rendered fat can be really deleterious to our animal's health and it can cause pancreatitis. Unless the manufacturer is adding a small amount of fish oil at the very end of the label as a supplement, I don't like to see
# 295.78 - 313.02
# oil at the top of my ingredients. So seeing oil in the ingredients is a big no -no. The next one is carbohydrates. Now no matter your stance on it, our animals do benefit from a low carbohydrate sources in the label on the back. So any kind of flowers, any
# 313.02 - 329.92
# kind of cereal, potatoes, legumes, I'm very, very wary. And I will only accept it if there is maybe one or two and if they are quite far down on the list of ingredients, because as we said before, they don't contain so much water to start with. So their weight
# 329.92 - 341.02
# is actually will make up more of the food than some of the fresh meat. So by now, if I still have the bag in my hand, that means that I'm looking at some good quality food. The last thing that I need to look at is actually the most important
# 341.02 - 357.68
# thing, which is what kind of protein source. I like to see whole names. Basically what I would find at the grocery store if I were shopping for myself. So beef, lamb, whole eggs, salmon, all of those are wonderful options. I actually do the same for other ingredients such as
# 357.68 - 375.42
# berries and vegetables. Now I actually prefer to give berries as a snack. They're a very good option and they're very kibble diet. So I would prefer to feed it as a snack, but if they are present in whole amounts and with whole words, not powders or flowers, but actually
# 375.42 - 388.94
# cranberries or blueberries, then I'm okay with that. And finally, I look at the unreadables, the ones that we can definitely not decode. And we don't have to. What I do is I look at how long the list of unreadables is. If it's fairly short, one line or two, then
# 388.94 - 400.28
# I'm okay with it. But if it's very, very long and it's more than half of the list of ingredients, then I would prefer not to feed it. So at this point, if the bag is still in my hand, then I ask myself, is this the right food for my
# 400.28 - 414.2
# animal right this moment? So I always have to think that every season requires different ingredients. These questions and more I've put into another video that I'm going to link for you over there so that you can also get a sense for some of the things that you need to
# 414.2 - 425.5
# watch out for to choose amongst the bags that have actually made it through all of that selection. If you made it this far, give us a like and help us spread the word to other pet owners who are also looking to figure out what exactly they're feeding their animals.
# 425.72 - 429.7
# Thank you for watching, give your animals a kiss from us, and we'll see you on the next one. Bye!
#
# How To Read Pet Food Labels With Holistic Veterinarian Dr. Katie Woodley (youtube.com)
#
# 0.9 - 16.94
# Do you know what goes into a pet food label? Now, it can be super confusing when you take a look at the bag or the can and wondering like what is that chicken dinner meal mean? Or even is there certain types of testing? That's what we're going to be
# 16.94 - 34.86
# talking about in this short video. I'm Dr. Katie Woodley, holistic veterinarian and founder of the Natural Pet Doctor. And in this brief video, I'm going to talk about some of the important factors that you need to know about as you read pet food labels to truly understand what it
# 34.86 - 50.88
# means, some of the food trials that go into making the pet food and also to what certain types of rules mean and what that can mean for when you see certain ingredients further down on the list or at the top of the list. So if you're excited about this,
# 51.18 - 69.48
# make sure you hit that subscribe button. And that way you can get notified when new content drops. And if you need more guidance and support, make sure you get our simple guide to improving your pet's food. I hope you enjoy these studies coming out that showcase that we can
# 69.48 - 85.46
# use food as medicine. We can change the disease processes all because of what we feed our pets and ourselves. So we're going to start with that pet food label. So if you have your food close to your pet's food, grab it because you're going to want to take a
# 85.46 - 99.3
# look at these and see as we go along, maybe you're going to see some of these ingredients or know what we're actually looking at. And then we can also answer your questions at the end too, based on some of the foods and brands you may be feeding. So there
# 99.3 - 114.14
# are a couple main parts that make up that pet food label. First, you're going to see the ingredient list. So it says ingredients, pretty obvious. It's going to list everything. You're going to notice that typically your vitamins and your minerals, the supplements are going to be listed at the
# 114.14 - 128.76
# back end of that. So a lot of those things that we can't pronounce it really well, those are going to be your synthetic vitamins and minerals. And then we have the next part typically that follows that is your guaranteed analysis. So this is going to tell us roughly how
# 128.76 - 147.06
# much protein, fat, fiber, moisture is present in these foods. And then at the bottom, typically you might have to look for this, is that AFCO statement. So let's talk about what that means a little bit more in depth. So pet food labeling is regulated at two different levels. The
# 147.06 - 167.22
# federal regulations, those are enforced by the the USF FDA. So the Food and Drug Administration. So what they do is they establish standards applicable for all animal feeds. They look at proper identification of the product, the net quantity statement, the manufacturer's name and address, and proper listing of ingredients.
# 167.92 - 188.38
# And then some states also enforce their own labeling regulations. But many states have adopted the model pet food regulations established by the Association of American Feed Control Officials, or AFCO. So you probably heard me say AFCO quite a bit. So that's what that means. It's actually a nonprofit organization
# 188.38 - 211.56
# that comes up with regulations that they recommend. It's not required though. These regulations though are more specific in nature. So they cover the different aspects of labeling such as product name, guaranteed analysis, the nutritional adequacy statement, feeding directions, and then also calorie statements. And the guaranteed analysis, this is
# 211.56 - 230.82
# going to indicate the minimum or maximum levels of nutrients. So like protein, fats, fiber, moisture, you are not going to find the amount of carbohydrates present in the food here though. We actually have to calculate that out for each food. So we talk about low carb foods, high carb
# 230.82 - 245.6
# foods. You're not going to find them on the label. So that can make it a little bit difficult to assess is this an appropriate carb content for say a cat. Also the fact that this is either minimum or maximum levels makes it difficult to determine if this is the
# 245.6 - 262.48
# optimal level for your pet. These are not guarantees of the quality of the food. And then of course moisture levels are going to vary between each product. So which also makes it really difficult to assess the carbohydrate content, the protein content present in the product you're looking at. So
# 262.48 - 277.74
# a lot of times we'll look at canned food and we'll look at the protein levels and we'll compare it to a dry food protein levels. And you're like, I thought canned food was higher in protein, but it looks lower. But then when we do the calculation and we convert
# 277.74 - 296.16
# everything to dry matter, that canned food is typically going to be higher in protein content. So it can be really confusing when you're just looking at those bare numbers on the back of the bag. The nutritional adequacy statement. So this is AFCO's statement on how the food is tested
# 296.16 - 311.4
# to determine if it's adequate for your pet. So the package states like typically the food supports all life stages. So if you see that, it can be a little bit confusing and a little bit make you feel a little bit weary of it. Because the problem with that is
# 311.4 - 330
# the product likely contains excessive nutrient levels that are necessary for most demanding life stage. So that's your kittens, that's growth. So kittens and puppies, they need those extra nutrients. So they're going to contain higher levels of protein, higher levels of calcium. But those levels may be inappropriate for say
# 330 - 347.42
# like a senior cat. So this is one of the many reasons why I advocate looking at your pet as an individual. Because those requirements change based on their life stage, based on their lifestyle, how active they are. And if there are any disease conditions, then we should be feeding
# 347.42 - 365.88
# the foods that are going to be appropriate for them. And then AFCO testing. So this is really interesting. So AFCO actually allows two basic methods for pet food manufacturers to substantiate their claims. You'd think food trials are required, right? How else are we going to know if pet thrives
# 365.88 - 385
# when they're eating foods, if we're not actually doing a trial and we're feeding it to them? However, most foods choose to formulate the food based on the AFCO nutrient profiles. This method, this is less time consuming and it's also cheaper for those companies. Because it only requires a calculation
# 385 - 403.28
# of the nutrient levels. So they can take that food and say, yep, ticks off the box for calcium requirements. Yep, ticks off the box for taurine. And the feeding trial method is technically gold standard. But here's the kicker. When we actually look at what goes into a feeding trial,
# 403.28 - 427.4
# you're going to be surprised. The protocol only requires six animals to pass based on a physical examination, not losing weight, but they can become overweight on that food. Because that's okay, right? No. And then four blood values over the length of only six months. It's insane when we look
# 427.4 - 441.82
# at that. So pet companies have stated that they can make a piece of leather fit those AFCO standards. And I'm pretty sure leather is not a healthy meal for a pet. Or I wouldn't want to feed that to my dog or my cat. I don't think they'd actually eat
# 441.82 - 459.02
# it, but it can fit the AFCO requirements. So for those foods that make complete and balanced claims, remember, we want balanced food. I talk about that a lot. So AFCO statements are going to be the bare minimum. Doesn't guarantee that that food is optimal. And most pet foods are
# 459.02 - 473.5
# going to have that AFCO statement on there. If you don't see this, run. Put it back, burn it. Do whatever, run from that brand if there's not an AFCO statement on there. But they make these balanced claims by three different definitions that you can see here that can appear
# 473.5 - 489.44
# on the package. So these are going to include product X is formulated to meet the nutritional levels established by the AFCO dog or cat nutrient profiles for life stage Y. So that's going to be just the test, not a food trial. Then the second one would be animal feeding
# 489.44 - 506.78
# tests using AFCO procedures substantiate that product X provides complete and balanced nutrition for life stage Y. So that's going to be those feeding trials with six pets passing it over six months. And then the final thing you may see, which is kind of the most confusing and blurry, is
# 506.78 - 526.66
# the product X provides complete and balanced nutrition for life stage Y. And it's comparable in nutritional adequacy to a product which has been substantiated using AFCO feeding trials. They're testing nutrient profiles. That's what that statement means. But it's confusing because they're throwing in the wording, the feeding trial. So
# 526.66 - 541.88
# those are things that you're going to look for in the back of the bag to see how is this food actually tested. These are a couple examples from labels that I just pulled off the internet. And so that first one you'll see the AFCO cat food nutritional facts. You'll
# 541.88 - 558.58
# see grain free real turkey recipe. Cat food is formulated to meet the nutritional levels established by the AFCO cat food nutrient profiles for all life stages. So this can be fed to kittens. It can be technically fed to senior cats. It fits all life stages. It hits the minimum,
# 558.84 - 578.54
# the maximum. It's not outside those ranges. And that food has not gone through a food trial. Whereas the other one, at the very bottom you'll see there, the AFCO statement, animal feeding tests using AFCO procedures substantiate that science diet adult advanced fitness original dog food provides complete and balanced
# 578.54 - 595.08
# nutrition for maintenance of adult dogs. So this doesn't say all life stages. So this is only for adult dogs, so not senior dogs. And then they've also done those animal feeding tests. So this gives you an example of the different things that you might read for those AFCO statements
# 595.08 - 611.44
# on the back of the food that you have. And that should be present on every single food. So dry, wet, any types of pet food that you're feeding, these should be present. So product name. This is a key factor of what we think about when we want to buy
# 611.44 - 628.98
# a product. So for that reason, manufacturers are going to use fancy names and other techniques to emphasize particular aspects of the product. This is where things get real sneaky. And so the percentages of named ingredients in that total product are going to be dictated by a few AFCO rules.
# 629.86 - 648.1
# So 95 % rule. What does that mean? So this applies to products consisting primarily of very few ingredients. So they're going to have, you're going to see simple names like beef for dogs or tuna cat food. So in these examples, at least 95 % of that product must be
# 648.1 - 668.34
# that named ingredient, so beef or tuna. So that's not counting the water added for processing. When we count the added water, that named ingredient still has to comprise 70 % of the product. Because ingredients list, they have to be listed in the proper order of the predominance ingredient by
# 668.34 - 687.3
# weight. Beef or tuna, for those examples, should be the first ingredient listed, followed often by water. And then we're going to see other compounds such as vitamins and minerals. The 25 % or dinner rule applies to many canned and dry products also. So if the named ingredients comprise at
# 687.3 - 707.1
# least 25 % of the product, not counting water, but less than 95%, the name has to include a qualifying descriptive term. So this is where we see foods use dinner as in beef dinner for dogs. And then counting that added water, those named ingredients still must comprise 10 %
# 707.1 - 726.76
# of the product. So we just went from 25 to potentially 10. So anywhere in there, you're going to see potentially other descriptors too. So we talked about dinner. However, if you see platter, entree, nuggets, formula, those are a few other examples that these pet food companies will use. To
# 726.76 - 742.34
# reduce the amount of higher cost proteins present in that food. So in the example, beef dinner for dogs, only a quarter of the product has to be beef. And beef would most likely be like the third or fourth ingredient on that ingredient list. So have a look at the
# 742.34 - 757.7
# foods that you're feeding right now and see if your company is potentially doing that. Because the primary ingredient is not always the named ingredient and may in fact actually be an ingredient that you don't want to feed to your pet. This is why we have to look at the
# 757.7 - 776.08
# ingredient list before repurchasing. So like a cat, let's talk about pet parents. Say you want to avoid buying a product that has fish in it. You're like, my cat doesn't like fish. I don't want fish. So I'm like, oh, this is fantastic. This food says chicken formula cat food.
# 776.84 - 795.68
# However, this is not probably the best choice since some chicken formulas, that's the added word may actually contain fish. And sometimes they actually contain even more fish than chicken. So another great reason why we need to be looking at that ingredient list and knowing what some of these words
# 795.68 - 815
# mean. And then the final one, so the 3 % rule or the with rule. So now AFCO model regulations allow the use of the term with as part of the product name. So dog food with beef, cat food with chicken. So now even a minor change in the wording
# 815 - 834.82
# of the name has a dramatic impact on the minimum amount of that named ingredient required. So for example, like a can of cat food with tuna could be confused with a can of tuna cat food, right? Super confusing. But the latter example has to contain at least 95 %
# 834.82 - 855.6
# tuna. So if it says tuna cat food, that has to be 95 % tuna. Whereas cat food with tuna only needs 3 % tuna. So we have to be reading these labels really carefully before we purchase to make sure that we're actually choosing the desired product. So this is
# 855.6 - 872.64
# an example of the 3 % rule. So notice the label at the top says with beef, right? Chopped ground dinner with beef sounds delicious, right? However, look at the ingredient list that I added to that picture. Where's beef? Takes a little while, right? I'm like, wait, shouldn't this say
# 872.64 - 890.3
# chopped ground dinner with chicken? However, so four to five ingredients down the list, we see beef. So if you wanted to avoid chicken, chicken's the first ingredient. But there's all sorts of other things going on with this food. So we also have meat byproducts, which by the way, when
# 890.3 - 911.5
# it's not specified. So you see meat byproducts, third ingredient on that ingredient list. That means any type of animal that can come from sick animals, animals that were already dead, that they brought to the slaughterhouse, diseased, horses, cows, dogs, cats, whatever that was not able to be used in
# 911.5 - 932.06
# human grade meat, it can be included. And this actually makes up the first ingredient. And we're going to talk a little bit about meat meal versus meat, but chicken is 75 % water. It's not dehydrated yet. And when we have meat byproducts, those are going to probably be higher
# 932.06 - 948.92
# than chicken. So super scary. And then also when we look further down, so I'm looking at these ingredients. Not super impressed by this food. Carrageenan is on there. And why they use that, we find these in a lot of wet foods because it gives that texture to the wet
# 948.92 - 964.76
# food. And it's actually a known GI irritant. If you have a dog, especially cats, and they're on a canned food, and they're just so sensitive, you need to be making sure that carrageenan is not in that food. Because a lot of times when you take them off that food,
# 965.22 - 980.52
# the inflammation goes away, they stop vomiting, they stop having diarrhea, and your problem is solved. So just don't even feed this product. Horrible. But I wanted to show you, it's a great example, how a company will use with and the label, but they can get away with chicken being
# 980.52 - 999.22
# a bigger proportion of that food than the actual beef. And so that's that 3 % rule. Ingredient lists. Okay, hopefully you have your bags of food. So checking out those ingredient lists. You're following along. This is about empowering you so you know how to optimize your pet's health through
# 999.22 - 1018.24
# food. I want you to look at this ingredient list. I want you to ask yourself, would I feed this to my puppy? Do you think these ingredients lead to optimal health? This is actually one of the big brands, and it's made specifically for Golden Retriever puppies. So let's break
# 1018.24 - 1036.08
# down the ingredient list a little bit and what you need to be looking for. So remember, all these ingredients, they're required to be listed in order of predominance by weight. So the weights of ingredients, their determinants are added in the formulation. So that's including their inherent water content. So
# 1036.08 - 1055.42
# this latter fact's really important when we're evaluating the relative quantity claims, especially when ingredients of different moisture contents are being compared. So this is especially true when we're comparing canned versus your bagged food. So your dry kibbles, they're going to be very different. So for example, one pet food
# 1055.42 - 1072.58
# may list meat as its first ingredient and corn as the second ingredient. So like even if it says chicken. So the manufacturer is not going to hesitate to point out that its competitor lists corn first and meat meal as second, suggesting that that competitor's product has less animal source
# 1072.58 - 1090.78
# protein than its own. However, that meat is really high in moisture. So about 75 % water. And on the other hand, the water and fat are already removed from meat meal. So it's only 10 % moisture. So what's left is mostly protein and minerals. So if we could compare
# 1090.78 - 1108.1
# both products on a dry matter basis, so this means we remove water from both ingredients, we can actually see that the second product actually had more animal source protein from meat meal than the first product had from meat, even though the ingredient list would suggest otherwise. So this is
# 1108.1 - 1124.34
# not to say that the second product has more meat than the first or in fact any meat at all. Meat meal is an interesting rabbit hole to go down to because most of the fat and water have been removed by rendering. So rendering is a whole nother topic that
# 1124.34 - 1143.56
# is a way to use cheaper proteins in pet foods. So, but keep in mind, your ingredients must be listed by common or usual names too. Ingredient splitting. So this is where the cheaper products broken into smaller portions to appear that they, like they make up less of the diet.
# 1143.76 - 1166.36
# So this is a tricky way of subdividing a more abundant, but cheaper ingredient into smaller portions. So looking at these two labels, there's a couple examples of ingredient splitting. For example, you may see corn broken down into corn gluten meal, corn flour, whole ground corn. There's also whole wheat
# 1166.36 - 1188.58
# flour, ground yellow corn. There's rice flour, soy flour, there's corn gluten meal in that top one, whole grain corn, flax seed, soybean meal, there's wheat gluten. So what it's doing by doing this ingredient splitting, the weight of the corn is now divided into three, which allows meat to actually
# 1188.58 - 1207.28
# look like it's the number one or second ingredient in the food, even though it's not. So look for that in that ingredient list. And another tactic that pet food companies use is with salt. So AFCA recommends that dry dog food contains at least 0 .3 % sodium and that
# 1207.28 - 1225.8
# dry cat food contains at least 0 .2 % sodium for both maintenance and to support normal growth and development. So those are the minimum recommended levels. However, there's this thing called the salt rule. And because most pet foods use similar formulas, the rule of thumb is typically that any
# 1225.8 - 1243.62
# ingredient that follows salt on the list must make up less than 1 % of the diet. So this has to be true for ingredients like vitamins and trace minerals because only small amounts are needed. So we can use salt on an ingredient list as a convenient marker of quantity.
# 1244.36 - 1261
# So if you, what pet food companies will do is put beautiful pictures of real food on their bags, like blueberries, broccoli, carrots, like all sorts of things, right? We like that. We feel like we're feeding that. However, if you think your pet food has a lot of healthy ingredients
# 1261 - 1278.32
# like blueberries and real food, go to the ingredient list and see where salt is. If it's listed after salt, there's probably a sprinkle or one blueberry in that entire bag. So they're tricking us. So when we see that, I kind of go, that company just made me kind of
# 1278.32 - 1295.82
# angry. Like that's irritating. But we can also look at the first part of the ingredient list. I don't always discount companies that do this, but if everything else that they're doing is right. But this is something we need to be aware of. Thanks for watching that short clip that
# 1295.82 - 1312.5
# was taken from our Better Gut Health program and is included also in our 21 -Day Better Gut Health Challenge. Knowing what to feed your pets is really, really important. So once again, I invite you to grab our free guide on how to improve your pet's food where you'll get
# 1312.5 - 1312.5
# more feedback, recommendations, even recipes and how to transition your dogs and cats to a higher quality food so we can help improve their overall health. I look forward to seeing you all in our next video. Take care. Bye -bye. on how to improve your pet's food where you'll get
# 1312.5 - 1343.98
# more feedback, recommendations, even recipes and how to transition your dogs and cats to a higher quality food so we can help improve their overall health. I look forward to seeing you all in our next video. Take care. Bye -bye.
# 3. Exposed: How Processed Pet Food Can Harm Your Pet | Holistic Vet's Advice (youtube.com)
#
# 0 - 26.04
# The food you're feeding your pets is the safest form of medicine or could be the slowest form of poison. Hey there pet parents, I'm Dr. Katie Woodley, the natural pet doctor. Do you know what meat meal on a pet food label really means? Today we're uncovering how processed pet
# 26.04 - 47
# food could be messing with your pet's gut health. Seriously affecting everything from nutrient absorption to behavior issues. If terms like microbiome health and gut brain access sound important to you, you don't want to miss this. So hit that subscribe button, ring the bell for some eye -opening truths that
# 47 - 66.64
# could be a game -changer for your pet's well -being. Enjoy. So processed pet food diets, right? So okay, let's get down into this. Now we're going deep. So most pet food companies are owned by global huge companies, right? So we're talking about Procter and Gamble. They're the makers of
# 66.64 - 87.54
# Yukonuba. I am Colgate Palm Olive. Yep, the people that make toothpaste, guess what they make? Hill Science Diet and Mars. Like companies that are making candy are making our pet foods. It is insane. So those are things that we need to look at. Who owns who? Who's being produced
# 87.54 - 101.18
# by who? What is going on there? And it doesn't mean that they can't produce a good product, but we can be smarter than them and ask the right questions. So how is Kibble made? I hope you're ready. This is going to be a long one, but we're going to
# 101.18 - 117.7
# go deep into how it's made and how it affects the overall quality and how it affects the health of your pets. So first off, we've got to bring all the raw materials together. So for dry pet foods, the main raw materials are going to be meat, fat, grains, along
# 117.7 - 142.44
# with concentrated vitamins and minerals. Those are usually coming to most pet food manufacturers as a pre -mix that comes from overseas. These raw materials, they arrive at the factory in train cars or in semi -trucks often come in large bags, weighing 25 to 50 pounds. The raw materials are
# 142.44 - 157.42
# stored in different holding areas until they're ready for processing. And then, so the other thing is too, we're going to talk about rendering. And there are some pictures that are not the most pleasant pictures that is my disclaimer coming up. They are very sad. They make me really sick
# 157.42 - 175.8
# and they really irritate me, but we also have to know where these things are coming from and what is actually happening. So you'll see some pictures of animals that will not make you feel good, but this is what's happening. Those are raw materials. They're sitting there until they're ready
# 175.8 - 190.68
# to be available. So keep that in mind as you're, as you're listening to me go through the process of how kibble is manufactured and how it is made. So then next, what they do is they grind together the raw materials. So after it's all assembled, they have to prepare
# 190.68 - 209.5
# them by getting, grinding them down to the appropriate particle size. So this helps also break apart the ingredients so that the nutrients can be more readily available. And the interesting thing is, is finding this information on different sites. It, this sounds very rosy. So keep that in mind. And
# 209.5 - 225.08
# obviously you can tell like, this is not a rosy situation. So keep that we're going to go through some things that are going to be disturbing as I go through this. The next thing is, is compounding mixing those ingredients. So we've ground it up, making it more available, maybe.
# 225.78 - 243.22
# And then what we're going to do is we're going to put them together. So there's this large blender that's usually used to blend these raw materials and batches up to 2000 pounds at a time. So during this stage, only the dry materials are mixed. Then they're stored until we're
# 243.22 - 261.86
# ready for the next step. That's where we come up to extrusion. So this is similar to kind of at super high temperatures where we're blasting it. So the materials are mixed, needed, proofed, shaped, sliced. And to begin the process, a preconditioner is used to measure out the dry mix
# 261.86 - 279.78
# and to blend it with the right amount of liquid ingredients. I couldn't find what this preconditioner is. I'm guessing it's some chemical to help it mold together. That's the other thing. Chemicals can be in this food and not listed on the ingredient list. So that an extruder then, is
# 279.78 - 300.72
# this big cylindrical barrel with multiple segments and a large screw that moves, mixes, and cooks the material before forcing it through that die cut where it's cut to the appropriate size. Next up is drying and cooling. So after those pieces are extruded at really high temperatures, those pieces of
# 300.72 - 317.36
# kibble are still soft. They're a bit spongy due to the moisture content. Well, we can't have that because they're going to get moldy. So the next step is drying it out at high temperatures once again and allowing it to cool. So another high heat cooking process. And then finally,
# 317.36 - 333.4
# we have a process called enrobing. This is the final step where the dry dog and cat foods are made. And in this process, this is exciting. I hope you're ready for this. This is where a liquid or powder is added to the outer surface of the kibble to enhance
# 333.4 - 355.36
# the flavor and palatability of the final product. Yep. Kibble off of the rack. It's not tasty. Dog will not eat it and a cat definitely will not eat it. So they actually have to spray the kibble with usually fats, oils that come from the rendering factory and can oxidize,
# 355.68 - 372.66
# ...
# 187.7 - 206.38
# the carbohydrate percentage levels in dog food by looking at the guaranteed analysis panel on the back of the bag. Pet food manufacturers hide the carbohydrate levels in the food. Many simply don't add them. Look at the ingredients panel on the bag of kibble. It's the pet food industry's version
# 206.38 - 224.5
# of the nutrition panel on human food products in the US and Canada. There you'll see five plus entries. The starch percentage will most likely be missing. You'll see crude protein, crude fat, crude fiber, moisture and ash in percentage values, for example. And if you don't see ash, just make
# 224.5 - 239.98
# it 7 % and add it. As I said, most likely the entry for dietary starch will be missing. This is the carbohydrates you will now be able to easily work out. So add up the four numbers of the nutrition panel to get a value. This includes crude protein, crude
# 239.98 - 260.28
# fat, moisture and ash. Then subtract from 100 and the remaining number is the estimated carbohydrate value in the food. Now you know the carbohydrate level of that bag of kibble. Number two. Following on from number one is that the ingredients in kibble must not contain corn, rice, potatoes, wheat,
# 260.46 - 283.32
# soil, barley. These ingredients are high in carbohydrates, often GMO or genetically modified organisms, contaminated with mycotoxins and with high levels of glyphosate in them. Carbohydrates in pet food convert to simple sugars very quickly once consumed. This spikes insulin at every meal, causing stress on the pancreas, liver and kidneys,
# 283.92 - 302.98
# unchecked yeast growth and leading to ear infections, urine infection, itchy skin, allergies, obesity, diabetes and even cancer. And number three. As I just mentioned, the kibble must contain naturally derived vitamins and minerals because the synthetic alternatives is not very well absorbed or even widely recognized by your dog's digestive
# 302.98 - 322.78
# system and often seen as foreign objects and expelled from the body as smelly, expensive and very concentrated urine. Synthetics also lead to health issues with acidosis, stones and UTIs. So it's important to pick a kibble with natural vitamins and minerals. Number four is the protein levels of the kibble.
# 323.36 - 340.52
# They need to be as high as possible, preferably 30 % plus on a dry weight basis, that's important, and has to be at least 75 % animal based protein. So make sure that the first three ingredients on the nutrition panel are animal based. And you want twice the protein
# 340.52 - 357
# levels of the fat content of the kibble, so if the kibble is 26 % protein, you want 13 % fats. And number five. The kibble must have ingredients you know the origin of and where they were made. This one is tricky when the manufacturer states proudly made in the
# 357 - 373.88
# USA and the ingredients are shipped over from China. So always be chasing up the pet food manufacturer for their pet food ingredient origins and stay vigilant.
# "
#
# --------------------------------------------------------------------------------
# default_assistant2024-07-13 16:04:51.236 | INFO     | autogenstudio.web.app:message_handler:38 - ** Processing Agent Message on Queue: Active Connections: ['6b4b331d-8267-450a-a92e-ce03cec7cc36', '4c6b37d0-1196-4540-b6a5-01e29ba2f97d'] **
# 2024-07-13 16:04:51.236 | INFO     | autogenstudio.web.app:message_handler:50 - Skipping message for connection_id: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d. Connection ID: 6b4b331d-8267-450a-a92e-ce03cec7cc36
# 2024-07-13 16:04:51.236 | INFO     | autogenstudio.web.app:message_handler:45 - Sending message to connection_id: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d. Connection ID: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d
#  (to user_proxy):
#
# To create a system prompt for your AI assistant, Freddie, for dog owners based on the provided text, we need to summarize the key points and instructions in a clear and concise manner. The prompt should guide Freddie to provide useful information to dog owners about reading pet food labels effectively.
#
# Here is the system prompt:
#
# ---
#
# **System Prompt for Freddie, the AI Assistant for Dog Owners:**
#
# Freddie, you are an AI assistant designed to help dog owners make informed decisions about their pets' nutrition. Your task is to provide clear and concise guidance on how to read pet food labels effectively. Use the following key points to assist dog owners:
#
# 1. **Importance of Reading Labels:**
#    - Explain why it's crucial to read pet food labels, emphasizing that pets rely on us to choose their food since they can't hunt for their own meals.
#
# 2. **Order of Ingredients:**
#    - Highlight that ingredients are listed in order of their pre-cooked weight, with the first ingredient being the most abundant. However, note that the weight of meat decreases significantly after cooking due to water loss, while grains and powders retain their weight.
#
# 3. **Key Ingredients to Watch:**
#    - Advise dog owners to look for high-quality ingredients such as whole meats (e.g., beef, lamb, whole eggs, salmon) and avoid low-quality ingredients like meat meals, protein powders, and rendered fats.
#    - Explain the difference between meat and meat byproducts, and why some byproducts can be acceptable (e.g., clean internal organs) while others (e.g., bones, feet, heads) are less desirable.
#
# 4. **Tricks for Quick Label Reading:**
#    - Provide a quick method for evaluating labels: check for the presence of terms like "meal," "powder," and "flour," and avoid products with these as primary ingredients.
#    - Look for oils and fats, ensuring they are high-quality animal fats rather than rendered fats or generic oils.
#
# 5. **Carbohydrates and Additives:**
#    - Emphasize the importance of low carbohydrate content and the potential negative effects of high-carb ingredients like cereals, grains, and legumes.
#    - Warn against synthetic vitamins and minerals, and explain the benefits of natural alternatives.
#
# 6. **AAFCO Statements:**
#    - Explain the significance of the AAFCO statement on pet food labels, which indicates whether the food meets nutritional standards. Clarify the difference between foods tested through feeding trials and those formulated to meet nutrient profiles.
#
# 7. **Ingredient Splitting and Misleading Labels:**
#    - Educate dog owners about ingredient splitting, where manufacturers list components separately to make them appear less significant.
#    - Caution against misleading terms like "with beef" or "chicken formula," which may contain minimal amounts of the named ingredient.
#
# 8. **Final Considerations:**
#    - Encourage dog owners to consider the overall ingredient quality, the presence of whole foods, and the length of the ingredient list, especially the number of unreadable or synthetic ingredients.
#    - Remind them to think about their pet's specific needs, such as life stage and activity level, when choosing food.
#
# Use this information to help dog owners make better choices for their pets' health and well-being.
#
# ---
#
# TERMINATE
#
# --------------------------------------------------------------------------------
# agent type <class 'autogenstudio.workflowmanager.ExtendedConversableAgent'>
# agent type <class 'autogenstudio.workflowmanager.ExtendedConversableAgent'>
# usage [{'agent': 'user_proxy', 'total_cost': 0, 'total_tokens': 0}, {'agent': 'default_assistant', 'total_cost': 0.085605, 'total_tokens': 15807}]
# None
# INFO:     127.0.0.1:64518 - "GET /api/profiler/18?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# Client #4c6b37d0-1196-4540-b6a5-01e29ba2f97d is disconnected
# Connection Closed. Total: 1
# INFO:     connection closed
# Client #6b4b331d-8267-450a-a92e-ce03cec7cc36 is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# INFO:     ('127.0.0.1', 49901) - "WebSocket /api/ws/6b4b331d-8267-450a-a92e-ce03cec7cc36" [accepted]
# New Connection: 6b4b331d-8267-450a-a92e-ce03cec7cc36, Total: 1
# INFO:     connection open
# INFO:     ('127.0.0.1', 49902) - "WebSocket /api/ws/4c6b37d0-1196-4540-b6a5-01e29ba2f97d" [accepted]
# New Connection: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d, Total: 2
# INFO:     connection open
# Client #4c6b37d0-1196-4540-b6a5-01e29ba2f97d is disconnected
# Connection Closed. Total: 1
# INFO:     connection closed
# Client #6b4b331d-8267-450a-a92e-ce03cec7cc36 is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# INFO:     ('127.0.0.1', 50467) - "WebSocket /api/ws/6b4b331d-8267-450a-a92e-ce03cec7cc36" [accepted]
# New Connection: 6b4b331d-8267-450a-a92e-ce03cec7cc36, Total: 1
# INFO:     connection open
# INFO:     ('127.0.0.1', 50468) - "WebSocket /api/ws/4c6b37d0-1196-4540-b6a5-01e29ba2f97d" [accepted]
# New Connection: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d, Total: 2
# INFO:     connection open
# Client #4c6b37d0-1196-4540-b6a5-01e29ba2f97d is disconnected
# Connection Closed. Total: 1
# INFO:     connection closed
# Client #6b4b331d-8267-450a-a92e-ce03cec7cc36 is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# INFO:     ('127.0.0.1', 60607) - "WebSocket /api/ws/6b4b331d-8267-450a-a92e-ce03cec7cc36" [accepted]
# New Connection: 6b4b331d-8267-450a-a92e-ce03cec7cc36, Total: 1
# INFO:     connection open
# INFO:     ('127.0.0.1', 60608) - "WebSocket /api/ws/4c6b37d0-1196-4540-b6a5-01e29ba2f97d" [accepted]
# New Connection: 4c6b37d0-1196-4540-b6a5-01e29ba2f97d, Total: 2
# INFO:     connection open
# Client #6b4b331d-8267-450a-a92e-ce03cec7cc36 is disconnected
# Connection Closed. Total: 1
# INFO:     connection closed
# Client #4c6b37d0-1196-4540-b6a5-01e29ba2f97d is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# INFO:     127.0.0.1:54884 - "GET / HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54886 - "GET /framework-cac843a6fec86b8bc39a.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54887 - "GET /webpack-runtime-8a9cec42747aac4b7ac0.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54884 - "GET /images/svgs/welcome.svg HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /app-528798f9e5263504af31.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54886 - "GET /page-data/index/page-data.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /page-data/app-data.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54892 - "GET /manifest.webmanifest HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /component---src-pages-index-tsx-63b85e072a7479d6d32f.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54886 - "GET /318ce576f236b79fd96f75904c13f6e55c3eee57-40536b969c9ad93bcc1c.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /favicon-32x32.png?v=46131b614287332146ea078703a67d38 HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54886 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /api/version HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54886 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 54896) - "WebSocket /api/ws/3c97e4a3-170d-4d21-b392-33cd6e5898ac" [accepted]
# New Connection: 3c97e4a3-170d-4d21-b392-33cd6e5898ac, Total: 1
# INFO:     connection open
# INFO:     127.0.0.1:54886 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /page-data/build/page-data.json HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /component---src-pages-build-tsx-bf9ad8b79ecb0e409aa9.js HTTP/1.1" 200 OK
# Client #3c97e4a3-170d-4d21-b392-33cd6e5898ac is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# INFO:     127.0.0.1:54885 - "GET /api/workflows?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54885 - "GET /api/agents?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54918 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54919 - "GET /api/version HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54918 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54918 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54919 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 54920) - "WebSocket /api/ws/ba255b09-89d0-474b-9e4d-385535d56b85" [accepted]
# New Connection: ba255b09-89d0-474b-9e4d-385535d56b85, Total: 1
# INFO:     connection open
# INFO:     127.0.0.1:54919 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54918 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54918 - "GET /api/workflows/1?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54919 - "GET /api/sessions/1/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# None
# INFO:     127.0.0.1:54921 - "GET /api/profiler/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54921 - "GET /355a6ca7-7d3ff1df35f7958f1b25.js HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54922 - "GET /614-45ec4d8cce7508cad991.js HTTP/1.1" 200 OK
# Client #ba255b09-89d0-474b-9e4d-385535d56b85 is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# INFO:     127.0.0.1:54926 - "GET /api/workflows?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54926 - "GET /api/models?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54928 - "GET /api/models?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54928 - "GET /api/agents?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54929 - "GET /api/sessions?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     ('127.0.0.1', 54930) - "WebSocket /api/ws/ba255b09-89d0-474b-9e4d-385535d56b85" [accepted]
# New Connection: ba255b09-89d0-474b-9e4d-385535d56b85, Total: 1
# INFO:     127.0.0.1:54931 - "GET /api/workflows/1?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     connection open
# INFO:     127.0.0.1:54932 - "GET /api/sessions/1/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54933 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54934 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54934 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54933 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54933 - "GET /api/workflows/4?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54934 - "GET /api/sessions/5/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54934 - "GET /api/workflows/2?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54933 - "GET /api/sessions/7/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54937 - "GET /api/workflows/3?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# INFO:     127.0.0.1:54938 - "GET /api/sessions/2/messages?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# None
# INFO:     127.0.0.1:54940 - "GET /api/profiler/8?user_id=guestuser@gmail.com HTTP/1.1" 200 OK
# Client #ba255b09-89d0-474b-9e4d-385535d56b85 is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# INFO:     ('127.0.0.1', 54964) - "WebSocket /api/ws/ba255b09-89d0-474b-9e4d-385535d56b85" [accepted]
# New Connection: ba255b09-89d0-474b-9e4d-385535d56b85, Total: 1
# INFO:     connection open
# Client #ba255b09-89d0-474b-9e4d-385535d56b85 is disconnected
# Connection Closed. Total: 0
# INFO:     connection closed
# ^C
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# ***** App stopped *****
# INFO:     Application shutdown complete.
# INFO:     Finished server process [80409]
